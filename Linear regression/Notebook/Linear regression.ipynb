# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('indian_bikes_dataset_1000.csv')

# %%
df.head()
# Out:
#            brand             model   cc  segment  year speedometer_type  \
# 0          Honda        Hornet 2.0  184      mid  2020          Digital
# 1          Bajaj       Pulsar N250  249      mid  2024          Digital
# 2           Hero     Splendor Plus   97   budget  2020           Analog
# 3  Royal Enfield  Thunderbird 350X  346  premium  2025     Semi-Digital
# 4  Royal Enfield         Scram 411  411  premium  2023     Semi-Digital
#
#    top_speed_kmh  mileage_kmpl  fuel_tank_liters  factory_price_inr  \
# 0            137          43.8              10.1             100781
# 1            157          33.2              14.9             123438
# 2             95          64.2               8.7              60156
# 3            152          29.1              17.3             146875
# 4            165          23.4              14.9             166412
#
#    gst_rate_pct  gst_amount_inr  ex_showroom_inr  on_road_price_inr  \
# 0          28.0           28219           129000             147604
# 1          28.0           34562           158000             185890
# 2          28.0           16844            77000              89751
# 3          28.0           41125           188000             221689
# 4          31.0           51588           218000             251257
#
#    overall_score  price_increase_scenario_pct           buyer_behaviour  \
# 0             70                          9.3  Will likely switch brand
# 1             71                          4.1          Might reconsider
# 2             57                          2.3          Might reconsider
# 3             67                          8.7  Will likely switch brand
# 4             73                         13.1    Will definitely switch
#
#   price_sensitivity
# 0              High
# 1            Medium
# 2            Medium
# 3              High
# 4         Very High

# %%
df.head(5)
# Out:
#            brand             model   cc  segment  year speedometer_type  \
# 0          Honda        Hornet 2.0  184      mid  2020          Digital
# 1          Bajaj       Pulsar N250  249      mid  2024          Digital
# 2           Hero     Splendor Plus   97   budget  2020           Analog
# 3  Royal Enfield  Thunderbird 350X  346  premium  2025     Semi-Digital
# 4  Royal Enfield         Scram 411  411  premium  2023     Semi-Digital
#
#    top_speed_kmh  mileage_kmpl  fuel_tank_liters  factory_price_inr  \
# 0            137          43.8              10.1             100781
# 1            157          33.2              14.9             123438
# 2             95          64.2               8.7              60156
# 3            152          29.1              17.3             146875
# 4            165          23.4              14.9             166412
#
#    gst_rate_pct  gst_amount_inr  ex_showroom_inr  on_road_price_inr  \
# 0          28.0           28219           129000             147604
# 1          28.0           34562           158000             185890
# 2          28.0           16844            77000              89751
# 3          28.0           41125           188000             221689
# 4          31.0           51588           218000             251257
#
#    overall_score  price_increase_scenario_pct           buyer_behaviour  \
# 0             70                          9.3  Will likely switch brand
# 1             71                          4.1          Might reconsider
# 2             57                          2.3          Might reconsider
# 3             67                          8.7  Will likely switch brand
# 4             73                         13.1    Will definitely switch
#
#   price_sensitivity
# 0              High
# 1            Medium
# 2            Medium
# 3              High
# 4         Very High

# %%
## scatter plot 
plt.scatter(df['top_speed_kmh'], df['mileage_kmpl'])
plt.xlabel("top speed")
plt.ylabel("mileage")
plt.title("top speed vs mileage")
# Out:
# Text(0.5, 1.0, 'top speed vs mileage')

# %%
## correlation 
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 ## correlation
# ----> 2 df.corr()
#
# File c:\Users\nit10\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:11076, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11072         """  # noqa: E501
#   11073         data = self._get_numeric_data() if numeric_only else self
#   11074         cols = data.columns
#   11075         idx = cols.copy()
# > 11076         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11077
#   11078         if method == "pearson":
#   11079             correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\nit10\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:2002, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1998                [2, 4.5, Timestamp('2000-01-02 00:00:00')]], dtype=object)
#    1999         """
#    2000         if dtype is not None:
#    2001             dtype = np.dtype(dtype)
# -> 2002         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003         if result.dtype is not dtype:
#    2004             result = np.asarray(result, dtype=dtype)
#    2005
#
# File c:\Users\nit10\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:1713, in BlockManager.as_array(self, dtype, copy, na_value)
#    1711         arr.flags.writeable = False
#    1712 else:
# -> 1713     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1714     # The underlying data was copied within _interleave, so no need
#    1715     # to further copy if copy=True or setting na_value
#    1717 if na_value is lib.no_default:
#
# File c:\Users\nit10\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:1772, in BlockManager._interleave(self, dtype, na_value)
#    1770     else:
#    1771         arr = blk.get_values(dtype)
# -> 1772     result[rl.indexer] = arr
#    1773     itemmask[rl.indexer] = 1
#    1775 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Honda'

# %%
## seaborn
try:
    import seaborn as sns
except ModuleNotFoundError:
    sns = None

# %%
sns.pairplot(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 sns.pairplot(df)
#
# AttributeError: 'NoneType' object has no attribute 'pairplot'

# %%
df = pd.read_csv('student_scores.csv')

# %%
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
##scatter plot
plt.scatter(df['Hours'], df['Scores'])
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.title('Hours vs Scores')
# Out:
# Text(0.5, 1.0, 'Hours vs Scores')

# %%
 ## correlation
 df.corr()
# Out:
#            Hours    Scores
# Hours   1.000000  0.976191
# Scores  0.976191  1.000000

# %%
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\Users\nit10\AppData\Local\Programs\Python\Python313\Lib\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: pandas>=1.2 in c:\Users\nit10\AppData\Local\Programs\Python\Python313\Lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\Users\nit10\AppData\Local\Programs\Python\Python313\Lib\site-packages (from seaborn) (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\nit10\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\nit10\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\nit10\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\nit10\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\Users\nit10\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\Users\nit10\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\nit10\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\nit10\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\Users\nit10\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\Users\nit10\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\Users\nit10\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: ipykernel in c:\users\nit10\appdata\roaming\python\python313\site-packages (from -r requirements.txt (line 1)) (7.2.0)
# Requirement already satisfied: pandas in c:\users\arkar\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 2)) (2.3.3)
# Requirement already satisfied: numpy in c:\users\arkar\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 3)) (2.3.5)
# Requirement already satisfied: matplotlib in c:\users\arkar\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 4)) (3.10.9)
# Requirement already satisfied: seaborn in c:\users\arkar\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 5)) (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\arkar\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 6)) (1.7.2)
# Requirement already satisfied: comm>=0.1.1 in c:\users\nit10\appdata\roaming\python\python313\site-packages (from ipykernel->-r requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\nit10\appdata\roaming\python\python313\site-packages (from ipykernel->-r requirements.txt (line 1)) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\nit10\appdata\roaming\python\python313\site-packages (from ipykernel->-r requirements.txt (line 1)) (9.13.0)
# Requirement already satisfied: jupyter-client>=8.8.0 in c:\users\nit10\appdata\roaming\python\python313\site-packages (from ipykernel->-r requirements.txt (line 1)) (8.8.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in c:\users\nit10\appdata\roaming\python\python313\site-packages (from ipykernel->-r requirements.txt (line 1)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\nit10\appdata\roaming\python\python313\site-packages (from ipykernel->-r requirements.txt (line 1)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\nit10\appdata\roaming\python\python313\site-packages (from ipykernel->-r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: packaging>=22 in c:\users\arkar\appdata\local\programs\python\python313\lib\site-packages (from ipykernel->-r requirements.txt (line 1)) (25.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\arkar\appdata\local\programs\python\python313\lib\site-packages (from ipykernel->-r requirements.txt (line 1)) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in c:\users\nit10\appdata\roaming\python\python313\site-packages (from ipykernel->-r requirements.txt (line 1)) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in c:\users\arkar\appdata\local\programs\python\python313\lib\site-packages (from ipykernel->-r requirements.txt (line 1)) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\nit10\appdata\roaming\python\python313\site-packages (from ipykernel->-r requirements.txt (line 1)) (5.14.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\arkar\appdata\local\programs\python\python313\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\arkar\appdata\local\programs\python\python313\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\arkar\appdata\local\programs\python\python313\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\arkar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\arkar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\arkar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\arkar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (1.5.0)
# Requirement already satisfied: pillow>=8 in c:\users\arkar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\arkar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (3.3.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\arkar\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn->-r requirements.txt (line 6)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\arkar\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn->-r requirements.txt (line 6)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\arkar\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn->-r requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\arkar\appdata\local\programs\python\python313\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in c:\users\nit10\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\nit10\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in c:\users\nit10\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.20.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\nit10\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in c:\users\nit10\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\nit10\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\nit10\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in c:\users\nit10\appdata\roaming\python\python313\site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.8.7)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\arkar\appdata\local\programs\python\python313\lib\site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel->-r requirements.txt (line 1)) (4.5.1)
# Requirement already satisfied: six>=1.5 in c:\users\arkar\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\nit10\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\nit10\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\nit10\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.2.3)
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: C:\Users\arkar\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
import numpy as np

# %%
## independent
X = df[['Scores']]
X.head()
# Out:
#    Scores
# 0      21
# 1      47
# 2      27
# 3      75
# 4      30

# %%
## dependent feature
X = df[['Scores']]
Y = df[['Hours']]

# %%
X_series = df['Scores']
np.array(X_series).shape
# Out:
# (25,)

# %%
Y
# Out:
#     Hours
# 0     2.5
# 1     5.1
# 2     3.2
# 3     8.5
# 4     3.5
# 5     1.5
# 6     9.2
# 7     5.5
# 8     8.3
# 9     2.7
# 10    7.7
# 11    5.9
# 12    4.5
# 13    3.3
# 14    1.1
# 15    8.9
# 16    2.5
# 17    1.9
# 18    6.1
# 19    7.4
# 20    2.7
# 21    4.8
# 22    3.8
# 23    6.9
# 24    7.8

# %%
## train test split
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[42], line 2
#       1 ## train test split
# ----> 2 from sklearn.model_selection import train_test_split
#       3 X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.25 , random_state=42)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.25 , random_state=42)

# %%
X_train.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 X_train.shape
#
# NameError: name 'X_train' is not defined
